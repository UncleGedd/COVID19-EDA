# %% [markdown]
# ## Aggregate data from multiple sources

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Johns Hopkins data

# %%
# data cleaning and summing total events by country
def preprocess_summation(df, description):
    df = df.drop(['Province/State', 'Lat', 'Long'], axis=1).groupby(['Country/Region']).sum().reset_index()
    col_name = 'Total' + ' ' + description
    df[col_name] = df.apply(lambda r: sum(r[1:]), axis=1)
    df = df[['Country/Region', col_name]]
    df.columns = ['Country', col_name]
    df.replace({'Korea, South': 'South Korea', 'Czechia': 'Czech Republic', 'Taiwan*': 'Taiwan', 'US': 'United States'}, inplace=True)
    return df

# %%
df_confirmed = pd.read_csv('./csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')
total_infections = preprocess_summation(df_confirmed, 'Infected')
total_infections.shape
# Out:
# (155, 2)

# %% [markdown]
# ### Import 2018 GDP data
# https://data.worldbank.org/indicator/NY.GDP.MKTP.CD

# %%
df_gdp = pd.read_csv('./outside_data/GDP.csv')
df_gdp = df_gdp[['Country Name', '2018']]
df_gdp.columns = ['Country', 'GDP 2018']
df_gdp.replace({'Korea, Rep.': 'South Korea'}, inplace=True)
df_gdp.shape
# Out:
# (264, 2)

# %%
df = total_infections.merge(df_gdp, how='inner', on='Country')
df
# Out:
#                  Country  Total Infected      GDP 2018
# 0            Afghanistan             161  1.936297e+10
# 1                Albania             389  1.510250e+10
# 2                Algeria             561  1.737580e+11
# 3                Andorra             147  3.236544e+09
# 4    Antigua and Barbuda               7  1.610574e+09
# ..                   ...             ...           ...
# 135       United Kingdom           14802  2.855297e+12
# 136              Uruguay             174  5.959689e+10
# 137           Uzbekistan              55  5.049992e+10
# 138              Vietnam            1141  2.452137e+11
# 139               Zambia               4  2.672007e+10
#
# [140 rows x 3 columns]

# %% [markdown]
# ### Crime and Population data
# https://worldpopulationreview.com/countries/crime-rate-by-country/

# %%
df_crime = pd.read_csv('./outside_data/crime_pop.csv', header=0, names=['Country', 'Crime Index', 'Population 2020'])
df = df.merge(df_crime, how='inner', on='Country')

# %%
df.head()
# Out:
#        Country  Total Infected      GDP 2018  Crime Index  Population 2020
# 0  Afghanistan             161  1.936297e+10        73.26        38928.346
# 1      Albania             389  1.510250e+10        40.02         2877.797
# 2      Algeria             561  1.737580e+11        54.41        43851.044
# 3    Argentina             502  5.198715e+11        62.96        45195.774
# 4      Armenia             396  1.243309e+10        20.78         2963.243

# %% [markdown]
# ## Smoking data
# https://ourworldindata.org/smoking#prevalence-of-smoking-across-the-world
# Note that the column of interest is percentage of country aged 15+ who smoke

# %%
df_smoke = pd.read_csv('./outside_data/smoking.csv', header=0, names=['Country', 'Code', 'Year', 'Smoking 2016'])
df_smoke = df_smoke[df_smoke.apply(lambda r: r['Year'] == 2016, axis=1)]
df_smoke.drop(['Code', 'Year'], axis=1, inplace=True)
df_smoke.shape
# Out:
# (186, 2)

# %%
df = df.merge(df_smoke, how='inner', on='Country')

# %% [markdown]
# ### Gender data
# https://data.worldbank.org/indicator/SP.POP.TOTL.FE.ZS
# Percentage of females in 2018

# %%
df_gender = pd.read_csv('./outside_data/gender.csv')
df_gender = df_gender[['Country Name', '2018']]
df_gender.columns = ['Country', 'Females 2018']
df_gender.replace({'Korea, Rep.': 'South Korea'}, inplace=True)

# %%
df = df.merge(df_gender, how='inner', on='Country')

# %% [markdown]
# ### Age data
# https://worldpopulationreview.com/countries/median-age/

# %%
df_age = pd.read_csv('./outside_data/age.csv')
df_age = df_age[['Place', 'Median']]
df_age.columns = ['Country', 'Median Age']
df_age.shape
# Out:
# (214, 2)

# %%
df = df.merge(df_age, how='inner', on='Country')

# %%
df.to_csv('covid19.csv', index=False)

# %% [markdown]
# ### Find Correlations
# https://github.com/AutoViML/Auto_ViML

# %%
from autoviml.Auto_ViML import Auto_ViML
# Out:
# Imported Auto_ViML version: 0.1.489. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='GS',feature_reduction=True,
#                              Boosting_Flag=None,Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=0)
#
# To remove previous versions, perform 'pip uninstall autoviml'

# %%
X = df[df.columns[2:]]
y = df['Total Infected'].to_frame()

# %%
Auto_ViML(
    train=df,
    test="",
    target='Total Infected',
    Boosting_Flag=True,
    Binning_Flag=False,
    Add_Poly=False,
    Stacking_Flag=False,
    Imbalanced_Flag=False,
    verbose=2,
)
# Out:
# Train (Size: 98,8) has Single_Label with target: ['Total Infected']
# "
#  ################### Regression  ######################
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  6
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     7 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were ID or low-information variables
#
# No GPU available on this device
#     Completed Scaling of numeric data. There are no missing values in train
# Regression problem: hyperparameters are being optimized for mae
# ############## F E A T U R E   S E L E C T I O N  ####################
# Trying Feature Selection among 6 numeric variables...
#     No variables were removed since no highly correlated variables found in data
#     No Categorical feature selection since 0 categorical feature(s)...
# ############## F E A T U R E   S E L E C T I O N  ####################
# Trying Feature Selection among 6 numeric variables...
#     No variables were removed since no highly correlated variables found in data
#     Adding 0 categorical variables to reduced numeric variables  of 6
# Current number of predictors = 6
#     Finding Important Features using Boosted Trees algorithm...
#         using 6 variables...
#         using 4 variables...
#         using 2 variables...
# Found 6 important features
#     Selected Features: ['GDP 2018', 'Population 2020', 'Median Age', 'Females 2018', 'Crime Index', 'Smoking 2016']
# Starting Feature Engineering now...
#     No Entropy Binning specified or there are no numeric vars in data set to Bin
# ###############  M O D E L   B U I L D I N G ####################
# Rows in Train data set = 88
#   Features in Train data set = 6
#     Rows in held-out data set = 10
# Finding Best Model and Hyper Parameters for Target: Total Infected...
# CPU Count = 4 in this device
# Using XGBoost Model, Estimated Training time = 0.0 mins
#     Actual training time (in seconds): 17
# ###########  S I N G L E  M O D E L   R E S U L T S #################
# 5-fold Cross Validation rmse Score = 165711.7993
#     Best Parameters for Model = {'gamma': 32, 'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# ########################################################
# XGBoost Model Prediction Results on Held Out CV Data Set:
#     MAE = 5603.3805
#     MAPE = 6624%
#     RMSE = 10426.7145
#     MAE as % std dev of Actuals = 39.1%
#     Normalized RMSE (% of MinMax of Actuals) = 22%
#     Normalized RMSE (% of Std Dev of Actuals) = 73%
# ################# E N S E M B L E  M O D E L  ##################
# QuickML_Ensembling Model results:
#     LassoLarsCV = 41271.5959
#     LassoCV = 1183251.3308
#     RidgeCV = 833735.5790
#     Bagging2 = 348278.2338
# Based on trying multiple models, Best type of algorithm for this data set is LassoLarsCV
# #############################################################################
#     MAE = 182854.0664
#     MAPE = 24257%
#     RMSE = 474925.2986
#     MAE as % std dev of Actuals = 1277.0%
#     Normalized RMSE (% of MinMax of Actuals) = 992%
#     Normalized RMSE (% of Std Dev of Actuals) = 3317%
# After multiple models, Ensemble Model Results:
#     RMSE Score = 474925.29858
# #############################################################################
# Single Model is better than Ensembling Models for this data set.
# Could not plot Model Evaluation Results Metrics
#     Time taken for this Target (in seconds) = 22
# Plotting Feature Importances to explain the output of model
# ############### P R E D I C T I O N  O N  T E S T  #################
#     Time taken for this Target (in seconds) = 22
# Training model on complete Train data and Predicting using give Test Data...
#     No Entropy Binning specified or there are no numeric vars in data set to Bin
# Actual Training time taken in seconds = 0
#     Saving predictions to ./Total Infected/Total Infected_Regression_train_modified.csv
#     No Ensembling of models done since there is no Test file given.
# ###############  C O M P L E T E D  ################
# Time Taken in mins = 0.4 for the Entire Process
# (XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=32, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.05, max_delta_step=0, max_depth=10,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#               objective='reg:squarederror', random_state=99, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=99, subsample=0.5,
#               tree_method=None, validate_parameters=False, verbosity=0),
#  ['GDP 2018',
#   'Population 2020',
#   'Median Age',
#   'Females 2018',
#   'Crime Index',
#   'Smoking 2016'],
#      GDP 2018  Population 2020  Median Age  Females 2018  Crime Index  \
#  0   0.000476         0.001763    0.513514      0.817835     0.430944
#  1   0.008201         0.030237    0.351351      0.831855     0.652261
#  2   0.025052         0.031171    0.472973      0.890213     0.783759
#  3   0.000346         0.001822    0.587838      0.947445     0.135035
#  4   0.069554         0.017484    0.709459      0.855669     0.472162
#  ..       ...              ...         ...           ...          ...
#  93  0.006111         0.030155    0.773649      0.971785     0.569671
#  94  0.019906         0.006636    0.425676      0.204440     0.054137
#  95  0.138759         0.046939    0.770270      0.870171     0.486620
#  96  0.002642         0.002177    0.584459      0.906332     0.620271
#  97  0.011680         0.067407    0.432432      0.852233     0.557059
#
#      Smoking 2016  Total Infected  Total Infected_predictions
#  0       0.608200             389                   69.081871
#  1       0.309795             561                   94.209236
#  2       0.451025             502                  405.359863
#  3       0.503417             396                   43.952389
#  4       0.289294            4205                 2834.594238
#  ..           ...             ...                         ...
#  93      0.612756              70                   10.933723
#  94      0.612756            1519                  385.598755
#  95      0.462415           14802                 7890.967773
#  96      0.337130             174                   46.034290
#  97      0.473804            1141                  216.475433
#
#  [98 rows x 8 columns],
#      GDP 2018  Population 2020  Median Age  Females 2018  Crime Index  \
#  0   0.000476         0.001763    0.513514      0.817835     0.430944
#  1   0.008201         0.030237    0.351351      0.831855     0.652261
#  2   0.025052         0.031171    0.472973      0.890213     0.783759
#  3   0.000346         0.001822    0.587838      0.947445     0.135035
#  4   0.069554         0.017484    0.709459      0.855669     0.472162
#  ..       ...              ...         ...           ...          ...
#  93  0.006111         0.030155    0.773649      0.971785     0.569671
#  94  0.019906         0.006636    0.425676      0.204440     0.054137
#  95  0.138759         0.046939    0.770270      0.870171     0.486620
#  96  0.002642         0.002177    0.584459      0.906332     0.620271
#  97  0.011680         0.067407    0.432432      0.852233     0.557059
#
#      Smoking 2016  Total Infected  Total Infected_predictions
#  0       0.608200             389                   69.081871
#  1       0.309795             561                   94.209236
#  2       0.451025             502                  405.359863
#  3       0.503417             396                   43.952389
#  4       0.289294            4205                 2834.594238
#  ..           ...             ...                         ...
#  93      0.612756              70                   10.933723
#  94      0.612756            1519                  385.598755
#  95      0.462415           14802                 7890.967773
#  96      0.337130             174                   46.034290
#  97      0.473804            1141                  216.475433
#
#  [98 rows x 8 columns])
