# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pydotplus
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz

# %%
df = pd.read_csv('./covid19.csv')
df.head()
# Out:
#      Country  Total Infected      GDP 2018  Crime Index  Population 2020  \
# 0    Albania             123  1.510250e+10        40.02         2877.797
# 1    Algeria             264  1.737580e+11        54.41        43851.044
# 2  Argentina             387  5.198715e+11        62.96        45195.774
# 3    Armenia             249  1.243309e+10        20.78         2963.243
# 4  Australia            2044  1.433904e+12        42.70        25499.884
#
#    Smoking 2016  Females 2018  Median Age
# 0          28.7     49.063095        32.9
# 1          15.6     49.484268        28.1
# 2          21.8     51.237348        31.7
# 3          24.1     52.956577        35.1
# 4          14.7     50.199623        38.7

# %% [markdown]
# ## Find Correlations

# %%
X = df[df.columns[2:]]
y = df['Total Infected']
df[df.columns[1:]].corr()['Total Infected'][:]
# Out:
# Total Infected     1.000000
# GDP 2018           0.739781
# Crime Index       -0.070812
# Population 2020    0.483187
# Smoking 2016       0.088585
# Females 2018       0.045986
# Median Age         0.269258
# Name: Total Infected, dtype: float64

# %%
plt.scatter(df['GDP 2018'], df['Population 2020'])
plt.xlabel('GDP')
plt.ylabel('Population')
plt.title('GDP vs Population')
plt.show()

# %% [markdown]
# The scatter plot shows the following 3 outliers

# %%
df[(df['GDP 2018'] > 1e13) | (df['Population 2020'] > 400000)]
# Out:
#           Country  Total Infected      GDP 2018  Crime Index  Population 2020  \
# 17          China           81591  1.360815e+13        36.70      1439323.776
# 40          India             536  2.718732e+12        42.38      1380004.385
# 93  United States           53740  2.054434e+13        46.73       331002.651
#
#     Smoking 2016  Females 2018  Median Age
# 17          25.6     48.679374        37.4
# 40          11.5     48.023540        27.9
# 93          21.8     50.520015        38.1

# %% [markdown]
# China, India and US are outliers in the above dataset

# %% [markdown]
# ### Scale the data and perform a linear regression

# %%
X_s = StandardScaler().fit_transform(X)

# %%
est = sm.OLS(y, X_s)
est2 = est.fit()
print(est2.summary(xname=[*X.columns]))
# small pval, reject the null hypothesis that a feature has no effect
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:         Total Infected   R-squared (uncentered):                   0.539
# Model:                            OLS   Adj. R-squared (uncentered):              0.510
# Method:                 Least Squares   F-statistic:                              18.53
# Date:                Wed, 25 Mar 2020   Prob (F-statistic):                    3.75e-14
# Time:                        17:11:11   Log-Likelihood:                         -1063.4
# No. Observations:                 101   AIC:                                      2139.
# Df Residuals:                      95   BIC:                                      2154.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# GDP 2018         7837.3507   1170.948      6.693      0.000    5512.726    1.02e+04
# Crime Index      1427.9343   1334.187      1.070      0.287   -1220.762    4076.630
# Population 2020  1990.1226   1146.434      1.736      0.086    -285.836    4266.081
# Smoking 2016       -8.7994   1130.651     -0.008      0.994   -2253.426    2235.827
# Females 2018     -548.4347   1075.344     -0.510      0.611   -2683.262    1586.393
# Median Age       3231.8304   1528.958      2.114      0.037     196.465    6267.196
# ==============================================================================
# Omnibus:                      116.836   Durbin-Watson:                   1.598
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2577.746
# Skew:                           3.771   Prob(JB):                         0.00
# Kurtosis:                      26.572   Cond. No.                         3.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Random Forest and single Decision Tree

# %%
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(X_s, y)
print('score', rfr.score(X_s, y), '\n')
[print(c + '\t', f) for c,f in zip(df[df.columns[2:]], rfr.feature_importances_)]
# Out:
# score 0.878041031855444
#
# GDP 2018	 0.6399327116669591
# Crime Index	 0.050153920761243885
# Population 2020	 0.08359957339930538
# Smoking 2016	 0.08750481322571055
# Females 2018	 0.02553641088522451
# Median Age	 0.11327257006155668
# [None, None, None, None, None, None]

# %%
tree = DecisionTreeRegressor(max_depth=3)
tree.fit(X_s, y)
print('score', tree.score(X_s, y), '\n')
print('Feature Importances')
[print(c + '\t', f) for c,f in zip(df_small.columns[2:], tree.feature_importances_)]
# Out:
# score 0.8782762093798461
#
# Feature Importances
# GDP 2018	 0.6293421989946211
# Crime Index	 0.0
# Population 2020	 0.0
# Smoking 2016	 0.0
# Females 2018	 0.1524278298330546
# Median Age	 0.21822997117232426
# [None, None, None, None, None, None]

# %%
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=df.columns[2:])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# In this analysis, population was the single biggest predictor of COVID-19 infections. This makes sense given the huge outliers shown in the scatter plot above.  Next, remove those outliers and rerun the experiment

# %% [markdown]
# ## Remove outliers (China, United States, India) and rerun analysis

# %%
df_small = df[(df['Country'] != 'United States') & (df['Country'] != 'India') & (df['Country'] != 'China')]
X = df_small[df.columns[2:]]
y = df_small['Total Infected']

# %% [markdown]
# Show countries with highest populations now that outliers have been removed

# %%
df_small.sort_values(by='Population 2020', ascending=False).head(5)
# Out:
#        Country  Total Infected      GDP 2018  Crime Index  Population 2020  \
# 41   Indonesia             686  1.042173e+12        46.26       273523.615
# 71    Pakistan             972  3.145882e+11        44.58       220892.340
# 12      Brazil            2247  1.868626e+12        69.48       212559.417
# 68     Nigeria              44  3.972696e+11        64.64       206139.589
# 8   Bangladesh              39  2.740250e+11        64.98       164689.383
#
#     Smoking 2016  Females 2018  Median Age
# 41          39.4     49.643882        30.2
# 71          20.1     48.538075        23.8
# 12          13.9     50.829917        32.0
# 68           5.8     49.336114        18.4
# 8           23.0     49.387297        26.7

# %% [markdown]
# GDP and Population are NOT correlated

# %%
X = df_small[df_small.columns[2:]]
y = df_small['Total Infected']
df_small[df_small.columns[1:]].corr()['Total Infected'][:]
# Out:
# Total Infected     1.000000
# GDP 2018           0.523564
# Crime Index       -0.085892
# Population 2020    0.109215
# Smoking 2016       0.105613
# Females 2018       0.073535
# Median Age         0.322505
# Name: Total Infected, dtype: float64

# %%
plt.scatter(df_small['GDP 2018'], df_small['Population 2020'])
plt.xlabel('GDP')
plt.ylabel('Population')
plt.title('GDP vs Population')
plt.show()

# %% [markdown]
# ### Regression Analysis

# %%
X_s = StandardScaler().fit_transform(X)

# %%
est = sm.OLS(y, X_s)
est2 = est.fit()
print(est2.summary(xname=[*X.columns]))
# small pval, reject the null hypothesis that a feature has no effect
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:         Total Infected   R-squared (uncentered):                   0.284
# Model:                            OLS   Adj. R-squared (uncentered):              0.237
# Method:                 Least Squares   F-statistic:                              6.075
# Date:                Wed, 25 Mar 2020   Prob (F-statistic):                    2.18e-05
# Time:                        17:11:13   Log-Likelihood:                         -1017.6
# No. Observations:                  98   AIC:                                      2047.
# Df Residuals:                      92   BIC:                                      2063.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# GDP 2018         4447.4080   1116.326      3.984      0.000    2230.288    6664.528
# Crime Index      1244.7845   1178.768      1.056      0.294   -1096.350    3585.919
# Population 2020  -669.7556   1054.854     -0.635      0.527   -2764.787    1425.276
# Smoking 2016      135.8566   1026.557      0.132      0.895   -1902.975    2174.688
# Females 2018     -254.7507    958.701     -0.266      0.791   -2158.814    1649.312
# Median Age       1820.6249   1554.441      1.171      0.245   -1266.628    4907.878
# ==============================================================================
# Omnibus:                      132.937   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4958.207
# Skew:                           4.537   Prob(JB):                         0.00
# Kurtosis:                      36.644   Cond. No.                         3.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The adjusted R-squared value is quite low; this shows that the model doesn't explain the variation in the dependent variable

# %% [markdown]
# ### Random Forest and single Decision Tree

# %%
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(X_s, y)
print('score', rfr.score(X_s, y), '\n')
[print(c + '\t', f) for c,f in zip(df_small.columns[2:], rfr.feature_importances_)]
# Out:
# score 0.8737649225763897
#
# GDP 2018	 0.41191505780787074
# Crime Index	 0.021826231119519857
# Population 2020	 0.03758854860848051
# Smoking 2016	 0.22821092442337917
# Females 2018	 0.02904102961975078
# Median Age	 0.27141820842099895
# [None, None, None, None, None, None]

# %%
tree = DecisionTreeRegressor(max_depth=3)
tree.fit(X_s, y)
print('score', tree.score(X_s, y), '\n')
print('Feature Importances')
[print(c + '\t', f) for c,f in zip(df_small.columns[2:], tree.feature_importances_)]
# Out:
# score 0.9598414417305519
#
# Feature Importances
# GDP 2018	 0.12805583933797668
# Crime Index	 0.0
# Population 2020	 0.0
# Smoking 2016	 0.13454466836411108
# Females 2018	 0.31277203522290503
# Median Age	 0.4246274570750072
# [None, None, None, None, None, None]

# %%
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=df_small.columns[2:])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ### Remove countries with small infection rate

# %%
df = df_small[df_small['Total Infected'] > 300]
df.head()
# Out:
#       Country  Total Infected      GDP 2018  Crime Index  Population 2020  \
# 2   Argentina             387  5.198715e+11        62.96        45195.774
# 4   Australia            2044  1.433904e+12        42.70        25499.884
# 5     Austria            5283  4.552858e+11        23.23         9006.398
# 7     Bahrain             392  3.774620e+10        29.18         1701.575
# 10    Belgium            4269  5.427611e+11        42.50        11589.623
#
#     Smoking 2016  Females 2018  Median Age
# 2           21.8     51.237348        31.7
# 4           14.7     50.199623        38.7
# 5           29.6     50.829427        44.0
# 7           26.4     36.348252        32.3
# 10          28.2     50.593319        41.4

# %%
X = df[df.columns[2:]]
X_s = StandardScaler().fit_transform(X)
y = df['Total Infected']

# %%
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(X_s, y)
print('score', rfr.score(X_s, y), '\n')
[print(c + '\t', f) for c,f in zip(df_small.columns[2:], rfr.feature_importances_)]
# Out:
# score 0.8471308989733002
#
# GDP 2018	 0.3374008968315309
# Crime Index	 0.035813454126760264
# Population 2020	 0.049324312973719385
# Smoking 2016	 0.20126527315887285
# Females 2018	 0.08879929878075071
# Median Age	 0.287396764128366
# [None, None, None, None, None, None]

# %%
import xgboost as xgb

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)
xg_reg.fit(X_s, y)
print(xg_reg.score(X_s, y))
[print(c + '\t', f) for c,f in zip(df_small.columns[2:], xg_reg.feature_importances_)]
# Out:
# 0.5762210814194422
# GDP 2018	 0.12033115
# Crime Index	 0.1410468
# Population 2020	 0.21048173
# Smoking 2016	 0.12379423
# Females 2018	 0.12590872
# Median Age	 0.2784374
# [None, None, None, None, None, None]
