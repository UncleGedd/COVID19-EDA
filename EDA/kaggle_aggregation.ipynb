# %% [markdown]
# ## Combine my data with stuff from Kaggle

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_mine = pd.read_csv('./covid19.csv')
df_mine.shape
# Out:
# (102, 8)

# %%
df_kag = pd.read_csv('./kaggle/covid19countryinfo.csv')
df_kag
df_kag.columns = ['Region', 'Country', *df_kag.columns[2:]]
df_kag
df_kag = df_kag[['Country', 'density', 'urbanpop', 'quarantine', 'schools', 'publicplace', 'gatheringlimit', 'nonessential', 'smokers', 'hospibed', 'sex0', 'sex14', 'sex25', 'sex54', 'sex64', 'sex65plus', 'sexratio', 'lung', 'femalelung', 'malelung', 'healthexp', 'firstcase']]
df_kag.replace({'Korea, South': 'South Korea', 'Czechia': 'Czech Republic', 'Taiwan*': 'Taiwan', 'US': 'United States'}, inplace=True)

# %%
df = df_kag.merge(df_mine, how="inner", on="Country")
df.head()
# Out:
#        Country  density  urbanpop quarantine schools publicplace  \
# 0      Albania    105.0      63.0        NaN     NaN         NaN
# 1      Algeria     18.0      73.0        NaN     NaN         NaN
# 2    Argentina     17.0      93.0  3/20/2020     NaN         NaN
# 3      Armenia    104.0      63.0        NaN     NaN         NaN
# 4  Netherlands    593.0      44.0        NaN     NaN         NaN
#
#    gatheringlimit nonessential  smokers  hospibed  sex0  sex14  sex25  sex54  \
# 0             NaN          NaN    29.40       2.9  1.08   1.11   1.09   0.93
# 1             NaN          NaN      NaN       1.9  1.05   1.05   1.05   1.03
# 2             NaN          NaN    23.95       5.0  1.05   1.06   1.05   1.00
# 3             NaN          NaN    26.90       4.2  1.13   1.14   1.06   0.93
# 4             NaN          NaN      NaN       1.2  1.02   1.01   1.01   0.93
#
#    sex64  sex65plus  sexratio   lung  femalelung  malelung healthexp  \
# 0   0.95       0.87      0.98  11.67        7.02     17.04       774
# 1   1.01       0.89      1.03   8.77        5.03     12.81     1,031
# 2   0.94       0.71      0.98  29.27       20.16     42.59     1,390
# 3   0.84       0.67      0.94  23.86       16.17     35.99       883
# 4   0.87       0.64      0.90    NaN         NaN       NaN        43
#
#    firstcase  Total Infected      GDP 2018  Crime Index  Population 2020  \
# 0   3/7/2020             259  1.510250e+10        40.02         2877.797
# 1  2/24/2020             847  1.737580e+11        54.41        43851.044
# 2   3/2/2020            1054  5.198715e+11        62.96        45195.774
# 3  2/29/2020             571  1.243309e+10        20.78         2963.243
# 4  3/12/2020           13696  9.136585e+11        28.54        17134.872
#
#    Smoking 2016  Females 2018  Median Age
# 0          28.7     49.063095        32.9
# 1          15.6     49.484268        28.1
# 2          21.8     51.237348        31.7
# 3          24.1     52.956577        35.1
# 4          25.8     50.220944        42.6

# %%
# data cleaning and summing total events by country
def preprocess_summation(df, description):
    df = df.drop(['Province/State', 'Lat', 'Long'], axis=1).groupby(['Country/Region']).sum().reset_index()
    col_name = 'Total' + ' ' + description
    df[col_name] = df.apply(lambda r: r[-1], axis=1)
    df = df[['Country/Region', col_name]]
    df.columns = ['Country', col_name]
    df.replace({'Korea, South': 'South Korea', 'Czechia': 'Czech Republic', 'Taiwan*': 'Taiwan', 'US': 'United States'}, inplace=True)
    return df

# %%
df_deaths = pd.read_csv('./csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
total_deaths = preprocess_summation(df_deaths, 'Deaths')
df = df.merge(total_deaths, how='inner', on='Country')

# %%
df_recovered = pd.read_csv('./csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
total_recover = preprocess_summation(df_recovered, 'Recovered')
df = df.merge(total_recover, how='inner', on='Country')
df.head()
# Out:
#        Country  density  urbanpop quarantine schools publicplace  \
# 0      Albania    105.0      63.0        NaN     NaN         NaN
# 1      Algeria     18.0      73.0        NaN     NaN         NaN
# 2    Argentina     17.0      93.0  3/20/2020     NaN         NaN
# 3      Armenia    104.0      63.0        NaN     NaN         NaN
# 4  Netherlands    593.0      44.0        NaN     NaN         NaN
#
#    gatheringlimit nonessential  smokers  hospibed  sex0  sex14  sex25  sex54  \
# 0             NaN          NaN    29.40       2.9  1.08   1.11   1.09   0.93
# 1             NaN          NaN      NaN       1.9  1.05   1.05   1.05   1.03
# 2             NaN          NaN    23.95       5.0  1.05   1.06   1.05   1.00
# 3             NaN          NaN    26.90       4.2  1.13   1.14   1.06   0.93
# 4             NaN          NaN      NaN       1.2  1.02   1.01   1.01   0.93
#
#    sex64  sex65plus  sexratio   lung  femalelung  malelung healthexp  \
# 0   0.95       0.87      0.98  11.67        7.02     17.04       774
# 1   1.01       0.89      1.03   8.77        5.03     12.81     1,031
# 2   0.94       0.71      0.98  29.27       20.16     42.59     1,390
# 3   0.84       0.67      0.94  23.86       16.17     35.99       883
# 4   0.87       0.64      0.90    NaN         NaN       NaN        43
#
#    firstcase  Total Infected      GDP 2018  Crime Index  Population 2020  \
# 0   3/7/2020             259  1.510250e+10        40.02         2877.797
# 1  2/24/2020             847  1.737580e+11        54.41        43851.044
# 2   3/2/2020            1054  5.198715e+11        62.96        45195.774
# 3  2/29/2020             571  1.243309e+10        20.78         2963.243
# 4  3/12/2020           13696  9.136585e+11        28.54        17134.872
#
#    Smoking 2016  Females 2018  Median Age  Total Deaths  Total Recovered
# 0          28.7     49.063095        32.9            15               67
# 1          15.6     49.484268        28.1            58               61
# 2          21.8     51.237348        31.7            28              248
# 3          24.1     52.956577        35.1             4               31
# 4          25.8     50.220944        42.6          1175              260

# %%
df.columns = ['Country', 'Density', 'Urban Pop', 'Quarantine', 'Schools',
       'Public Place', 'Gathering Limit', 'Nonessential', 'Smokers', 'Hospital Beds',
       'sex0', 'sex14', 'sex25', 'sex54', 'sex64', 'sex65plus', 'Sex Ratio',
       'Lung', 'Female Lung', 'Male Lung', 'Health Exp', 'First Case',
       'Total Infected', 'GDP 2018', 'Crime Index', 'Population 2020',
       'Smoking 2016', 'Females 2018', 'Median Age', 'Total Deaths',
       'Total Recovered']

df.head()
# Out:
#        Country  Density  Urban Pop Quarantine Schools Public Place  \
# 0      Albania    105.0       63.0        NaN     NaN          NaN
# 1      Algeria     18.0       73.0        NaN     NaN          NaN
# 2    Argentina     17.0       93.0  3/20/2020     NaN          NaN
# 3      Armenia    104.0       63.0        NaN     NaN          NaN
# 4  Netherlands    593.0       44.0        NaN     NaN          NaN
#
#    Gathering Limit Nonessential  Smokers  Hospital Beds  sex0  sex14  sex25  \
# 0              NaN          NaN    29.40            2.9  1.08   1.11   1.09
# 1              NaN          NaN      NaN            1.9  1.05   1.05   1.05
# 2              NaN          NaN    23.95            5.0  1.05   1.06   1.05
# 3              NaN          NaN    26.90            4.2  1.13   1.14   1.06
# 4              NaN          NaN      NaN            1.2  1.02   1.01   1.01
#
#    sex54  sex64  sex65plus  Sex Ratio   Lung  Female Lung  Male Lung  \
# 0   0.93   0.95       0.87       0.98  11.67         7.02      17.04
# 1   1.03   1.01       0.89       1.03   8.77         5.03      12.81
# 2   1.00   0.94       0.71       0.98  29.27        20.16      42.59
# 3   0.93   0.84       0.67       0.94  23.86        16.17      35.99
# 4   0.93   0.87       0.64       0.90    NaN          NaN        NaN
#
#   Health Exp First Case  Total Infected      GDP 2018  Crime Index  \
# 0        774   3/7/2020             259  1.510250e+10        40.02
# 1      1,031  2/24/2020             847  1.737580e+11        54.41
# 2      1,390   3/2/2020            1054  5.198715e+11        62.96
# 3        883  2/29/2020             571  1.243309e+10        20.78
# 4         43  3/12/2020           13696  9.136585e+11        28.54
#
#    Population 2020  Smoking 2016  Females 2018  Median Age  Total Deaths  \
# 0         2877.797          28.7     49.063095        32.9            15
# 1        43851.044          15.6     49.484268        28.1            58
# 2        45195.774          21.8     51.237348        31.7            28
# 3         2963.243          24.1     52.956577        35.1             4
# 4        17134.872          25.8     50.220944        42.6          1175
#
#    Total Recovered
# 0               67
# 1               61
# 2              248
# 3               31
# 4              260

# %%
cols = df.columns.tolist()
total_infected_index = list(df.columns).index('Total Infected')
cols[len(cols)-3], cols[total_infected_index] = cols[total_infected_index], cols[len(cols)-3]
df = df[cols]
df.head()
df[df.Country == 'India']
# Out:
#     Country  Density  Urban Pop Quarantine Schools Public Place  \
# 116   India    464.0       35.0  3/25/2020     NaN          NaN
#
#      Gathering Limit Nonessential  Smokers  Hospital Beds  sex0  sex14  sex25  \
# 116              NaN          NaN    11.15            0.7  1.12   1.13   1.13
#
#      sex54  sex64  sex65plus  Sex Ratio   Lung  Female Lung  Male Lung  \
# 116   1.06   1.01        0.9       1.08  96.92        87.54     106.89
#
#     Health Exp First Case  Median Age      GDP 2018  Crime Index  \
# 116        238  1/29/2020        27.9  2.718732e+12        42.38
#
#      Population 2020  Smoking 2016  Females 2018  Total Infected  \
# 116      1380004.385          11.5      48.02354            1998
#
#      Total Deaths  Total Recovered
# 116            58              148

# %%
df.to_csv('covid19_by_country.csv', index=False)
